# %%
# BASIC PACKAGES
import pandas as pd
import numpy as np
import missingno as msno

# VISUALIZATION PACKAGES
import scikitplot as skplt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1= pd.read_csv('MFG10YearTerminationData.csv')

# %%
df1.shape
# Out:
# (49653, 18)

# %%
# CONFIRM NO MISSING VALUES

df1.isna().sum()
# Out:
# EmployeeID             0
# recorddate_key         0
# birthdate_key          0
# orighiredate_key       0
# terminationdate_key    0
# age                    0
# length_of_service      0
# city_name              0
# department_name        0
# job_title              0
# store_name             0
# gender_short           0
# gender_full            0
# termreason_desc        0
# termtype_desc          0
# STATUS_YEAR            0
# STATUS                 0
# BUSINESS_UNIT          0
# dtype: int64

# %%
# DTYPES SHOW SOME CATEGORICAL FEATURES ARE READ AS NUMERIC

df1.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %%
# CAST OBJECT TYPES AS NEEDED

df1.loc[:,'EmployeeID']= df1.EmployeeID.astype(object)
df1.loc[:,'store_name']= df1.EmployeeID.astype(object)
df1.loc[:,'STATUS_YEAR']= df1.EmployeeID.astype(object)

# %%
df1.head(10)
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
# 5            1/1/1900   57                 22  Vancouver       Executive
# 6            1/1/1900   58                 23  Vancouver       Executive
# 7            1/1/1900   59                 24  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# 9            1/1/1900   61                 26  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
# 5       CEO          35            M        Male  Not Applicable
# 6       CEO          35            M        Male  Not Applicable
# 7       CEO          35            M        Male  Not Applicable
# 8       CEO          35            M        Male  Not Applicable
# 9       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE
# 6  Not Applicable         2012  ACTIVE    HEADOFFICE
# 7  Not Applicable         2013  ACTIVE    HEADOFFICE
# 8  Not Applicable         2014  ACTIVE    HEADOFFICE
# 9  Not Applicable         2015  ACTIVE    HEADOFFICE

# %%
# DESCRIBE NUMERIC FEATURES

df1.describe()
# Out:
#                 age  length_of_service
# count  49653.000000       49653.000000
# mean      42.077035          10.434596
# std       12.427257           6.325286
# min       19.000000           0.000000
# 25%       31.000000           5.000000
# 50%       42.000000          10.000000
# 75%       53.000000          15.000000
# max       65.000000          26.000000

# %%
# DESCRIBE CATEGORICAL FEATURES

df1.describe(exclude=np.number).T
# Out:
#                      count unique              top   freq
# EmployeeID           49653   6284             1318     10
# recorddate_key       49653    130  12/31/2013 0:00   5215
# birthdate_key        49653   5342        3/23/1973     40
# orighiredate_key     49653   4415        9/25/2006     50
# terminationdate_key  49653   1055         1/1/1900  42450
# city_name            49653     40        Vancouver  11211
# department_name      49653     21            Meats  10269
# job_title            49653     47      Meat Cutter   9984
# store_name           49653   6284             1318     10
# gender_short         49653      2                F  25898
# gender_full          49653      2           Female  25898
# termreason_desc      49653      4   Not Applicable  48168
# termtype_desc        49653      3   Not Applicable  48168
# STATUS_YEAR          49653   6284             1318     10
# STATUS               49653      2           ACTIVE  48168
# BUSINESS_UNIT        49653      2           STORES  49068

# %%
# ISOLATE EMPLOYEES WHO CHURNED, THE TARGET CLASS OF THIS DATASET

df_churn= df1[df1['STATUS'] == 'TERMINATED']
df_churn
# Out:
#       EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 48168       1338   2/1/2009 0:00     2/16/1949        9/20/1989
# 48169       1339   2/1/2014 0:00     2/19/1949        9/22/1989
# 48170       1340   2/1/2009 0:00     2/19/1949        9/22/1989
# 48171       1341   2/1/2009 0:00     2/21/1949        9/23/1989
# 48172       1343   2/1/2014 0:00     2/24/1949        9/25/1989
# ...          ...             ...           ...              ...
# 49648       8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649       8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650       8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651       8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652       8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 48168           2/16/2009   60                 19    Vancouver
# 48169           2/19/2014   65                 24       Nelson
# 48170           2/19/2009   60                 19      Kelowna
# 48171           2/21/2009   60                 19    Vancouver
# 48172           2/24/2014   65                 24     Victoria
# ...                   ...  ...                ...          ...
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name                  job_title store_name gender_short  \
# 48168          Training         Director, Training       1338            M
# 48169  Store Management              Store Manager       1339            F
# 48170  Store Management              Store Manager       1340            M
# 48171   Labor Relations  Director, Labor Relations       1341            M
# 48172  Store Management              Store Manager       1343            F
# ...                 ...                        ...        ...          ...
# 49648             Dairy               Dairy Person       8258            M
# 49649  Customer Service                    Cashier       8264            F
# 49650  Customer Service                    Cashier       8279            F
# 49651  Customer Service                    Cashier       8296            F
# 49652  Customer Service                    Cashier       8321            F
#
#       gender_full termreason_desc termtype_desc STATUS_YEAR      STATUS  \
# 48168        Male      Retirement     Voluntary        1338  TERMINATED
# 48169      Female      Retirement     Voluntary        1339  TERMINATED
# 48170        Male      Retirement     Voluntary        1340  TERMINATED
# 48171        Male      Retirement     Voluntary        1341  TERMINATED
# 48172      Female      Retirement     Voluntary        1343  TERMINATED
# ...           ...             ...           ...         ...         ...
# 49648        Male          Layoff   Involuntary        8258  TERMINATED
# 49649      Female      Resignaton     Voluntary        8264  TERMINATED
# 49650      Female          Layoff   Involuntary        8279  TERMINATED
# 49651      Female      Resignaton     Voluntary        8296  TERMINATED
# 49652      Female          Layoff   Involuntary        8321  TERMINATED
#
#       BUSINESS_UNIT
# 48168    HEADOFFICE
# 48169        STORES
# 48170        STORES
# 48171    HEADOFFICE
# 48172        STORES
# ...             ...
# 49648        STORES
# 49649        STORES
# 49650        STORES
# 49651        STORES
# 49652        STORES
#
# [1485 rows x 18 columns]

# %%
# DESCRIBE CATEGORICAL FEATURES FOR CHURNED EMPLOYEES

df_churn.describe(exclude=np.number).T
# Out:
#                     count unique             top  freq
# EmployeeID           1485   1485            1338     1
# recorddate_key       1485    120  12/1/2014 0:00   152
# birthdate_key        1485   1358       2/14/1946     3
# orighiredate_key     1485   1290       11/4/1989     4
# terminationdate_key  1485   1054      12/30/2014   144
# city_name            1485     40       Vancouver   296
# department_name      1485     20           Meats   377
# job_title            1485     36     Meat Cutter   354
# store_name           1485   1485            1338     1
# gender_short         1485      2               F   915
# gender_full          1485      2          Female   915
# termreason_desc      1485      3      Retirement   885
# termtype_desc        1485      2       Voluntary  1270
# STATUS_YEAR          1485   1485            1338     1
# STATUS               1485      1      TERMINATED  1485
# BUSINESS_UNIT        1485      2          STORES  1416

# %% [markdown]
# Some initial observations:
# 1. About 60-65% of the churned employees are Female. Is this representative of the population?
# 2. About 60% of the employees churned due to Retirement. What are the ages of those retiring?
# 3. About 90% of the employees churned voluntarily. What are the main reasons?
# 4. The Meat department workers churn the most

# %%
#sns.countplot
print("Percentage of Females in population:", 
      round(len(df1[df1.gender_full == 'Female']) / len(df1),2),"%")
print("Percentage of Females in churned population:", 
      round(len(df_churn[df_churn.gender_full == 'Female']) / len(df_churn),2),"%")
# Out:
# Percentage of Females in population: 0.52 %
# Percentage of Females in churned population: 0.62 %

# %%
fig, ax = plt.subplots()
fig.patch.set_facecolor('white')
ax.set_xlabel('Age (Years)')
ax.set_ylabel('Count in Bin')
ax.set_title('Age Distribution')
sns.histplot(x='age', data=df1, bins=50, color='green', alpha=0.5)
sns.histplot(x='age', data=df_churn, bins=50, color='blue', alpha=0.5)
# Out:
# <AxesSubplot:title={'center':'Age Distribution'}, xlabel='Age (Years)', ylabel='Count in Bin'>

# %%
fig, ax = plt.subplots()
fig.patch.set_facecolor('white')
ax.set_xlabel('Age (Years)')
ax.set_ylabel('Count in Bin')
ax.set_title('Age Distribution of non-Retiree Churn')
sns.histplot(x='age', data=df_churn[df_churn.age < 60], bins=50, color='blue', alpha=0.5)
# Out:
# <AxesSubplot:title={'center':'Age Distribution of non-Retiree Churn'}, xlabel='Age (Years)', ylabel='Count in Bin'>

# %% [markdown]
# We see high attrition from the younger age groups, 20-30. Now let's look at the relationship between non-retiree churned employees as their job department and title.

# %%
fig, ax = plt.subplots()
sns.scatterplot(x='age',y='length_of_service', data=df_churn, hue='gender_full', 
                palette='Reds', alpha=0.1, ax=ax)
sns.scatterplot(x='age',y='length_of_service', data=df1, hue='gender_full', 
                palette='Blues', alpha=0.1, ax=ax)
plt.show()

# %%
# Employee stats
print("Number of unique employees in the study:" ,len(df1.EmployeeID.unique()))
print("Number of employees who churned during the 10 year study:", len(df1[df1['terminationdate_key'] != '1/1/1900']['EmployeeID'].unique()))
print("Avg Tenure (years) of Employees in the Dataset:", round(df1.groupby('EmployeeID')['length_of_service'].mean().mean(),2))
print("Avg Age of employees in the dataset: ", round(df1.groupby('EmployeeID')['age'].mean().mean(),2))
# Out:
# Number of unique employees in the study: 6284
# Number of employees who churned during the 10 year study: 1485
# Avg Tenure (years) of Employees in the Dataset: 9.45
# Avg Age of employees in the dataset:  41.31

# %%
pivot1 = pd.pivot_table(df1, values=['length_of_service', 'age'], index=['EmployeeID'],
                    aggfunc=np.mean)

# %%
pivot1
# Out:
#              age  length_of_service
# EmployeeID
# 1318        56.5               21.5
# 1319        53.5               21.5
# 1320        55.5               21.5
# 1321        51.5               21.5
# 1322        52.5               21.5
# ...          ...                ...
# 8332        20.0                1.0
# 8333        20.0                1.0
# 8334        20.0                1.0
# 8335        20.0                1.0
# 8336        20.0                1.0
#
# [6284 rows x 2 columns]
